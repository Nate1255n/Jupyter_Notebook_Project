# %%
import pandas as pd
import seaborn as sns

# %%
df = pd.read_csv('TWO_CENTURIES_OF_UM_RACES.csv')
# Out:
# C:\Users\Natna\AppData\Local\Temp\ipykernel_13848\107228863.py:1: DtypeWarning: Columns (11) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('TWO_CENTURIES_OF_UM_RACES.csv')

# %%
# number of rows and col
df.shape
# Out:
# (7117634, 13)

# %%
# gives column names and data types
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7117634 entries, 0 to 7117633
# Data columns (total 13 columns):
#  #   Column                     Dtype
# ---  ------                     -----
#  0   Year of event              int64
#  1   Event dates                object
#  2   Event name                 object
#  3   Event distance/length      object
#  4   Event number of finishers  int64
#  5   Athlete performance        object
#  6   Athlete club               object
#  7   Athlete country            object
#  8   Athlete year of birth      float64
#  9   Athlete gender             object
#  10  Athlete age category       object
#  11  Athlete average speed      object
#  12  Athlete ID                 int64
# dtypes: float64(1), int64(3), object(9)
# memory usage: 705.9+ MB

# %%
# summary of the stats
df.describe()
# Out:
#        Year of event  Event number of finishers  Athlete year of birth  \
# count   7.117634e+06               7.117634e+06           6.558280e+06
# mean    2.012990e+03               1.310716e+03           1.970613e+03
# std     9.074683e+00               2.973447e+03           1.264591e+01
# min     1.798000e+03               0.000000e+00           1.193000e+03
# 25%     2.011000e+03               8.700000e+01           1.963000e+03
# 50%     2.016000e+03               2.270000e+02           1.972000e+03
# 75%     2.019000e+03               7.690000e+02           1.980000e+03
# max     2.022000e+03               2.002700e+04           2.021000e+03
#
#          Athlete ID
# count  7.117634e+06
# mean   5.275223e+05
# std    4.634639e+05
# min    0.000000e+00
# 25%    1.304470e+05
# 50%    3.775990e+05
# 75%    9.164148e+05
# max    1.600755e+06

# %%
# first five rows
df.head(5)
# Out:
#    Year of event Event dates           Event name Event distance/length  \
# 0           2018  06.01.2018  Selva Costera (CHI)                  50km
# 1           2018  06.01.2018  Selva Costera (CHI)                  50km
# 2           2018  06.01.2018  Selva Costera (CHI)                  50km
# 3           2018  06.01.2018  Selva Costera (CHI)                  50km
# 4           2018  06.01.2018  Selva Costera (CHI)                  50km
#
#    Event number of finishers Athlete performance        Athlete club  \
# 0                         22           4:51:39 h               Tnfrc
# 1                         22           5:15:45 h  Roberto Echeverría
# 2                         22           5:16:44 h   Puro Trail Osorno
# 3                         22           5:34:13 h            Columbia
# 4                         22           5:54:14 h      Baguales Trail
#
#   Athlete country  Athlete year of birth Athlete gender Athlete age category  \
# ...

# %% [markdown]
# ## Cleaning up the Data

# %% [markdown]
# #### We only want USA Races, 50km or 50MI, for the year 2020

# %%
# Filtering the data for 50km
df.loc[df['Event distance/length'] == '50km']
# Out:
#          Year of event Event dates                         Event name  \
# 0                 2018  06.01.2018                Selva Costera (CHI)
# 1                 2018  06.01.2018                Selva Costera (CHI)
# 2                 2018  06.01.2018                Selva Costera (CHI)
# 3                 2018  06.01.2018                Selva Costera (CHI)
# 4                 2018  06.01.2018                Selva Costera (CHI)
# ...                ...         ...                                ...
# 7117228           2015  09.10.2015  West Virginia Trilogy 50 km (USA)
# 7117229           2015  09.10.2015  West Virginia Trilogy 50 km (USA)
# 7117230           2015  09.10.2015  West Virginia Trilogy 50 km (USA)
# 7117231           2015  09.10.2015  West Virginia Trilogy 50 km (USA)
# 7117232           2015  09.10.2015  West Virginia Trilogy 50 km (USA)
#
#         Event distance/length  Event number of finishers Athlete performance  \
# ...

# %%
# Combine 50km/50mi with isin

# %%
# filter for 50km/50mi

df.loc[df['Event distance/length'].isin(['50km', '50mi'])]
# Out:
#          Year of event Event dates                         Event name  \
# 0                 2018  06.01.2018                Selva Costera (CHI)
# 1                 2018  06.01.2018                Selva Costera (CHI)
# 2                 2018  06.01.2018                Selva Costera (CHI)
# 3                 2018  06.01.2018                Selva Costera (CHI)
# 4                 2018  06.01.2018                Selva Costera (CHI)
# ...                ...         ...                                ...
# 7117228           2015  09.10.2015  West Virginia Trilogy 50 km (USA)
# 7117229           2015  09.10.2015  West Virginia Trilogy 50 km (USA)
# 7117230           2015  09.10.2015  West Virginia Trilogy 50 km (USA)
# 7117231           2015  09.10.2015  West Virginia Trilogy 50 km (USA)
# 7117232           2015  09.10.2015  West Virginia Trilogy 50 km (USA)
#
#         Event distance/length  Event number of finishers Athlete performance  \
# ...

# %%
# filtering for 50km or 50mi and the year 2020

df.loc[(df['Event distance/length'].isin(['50km', '50mi'])) &
        (df['Year of event']== 2020)]
# Out:
#          Year of event     Event dates  \
# 2538571           2020  07.-09.02.2020
# 2538572           2020  07.-09.02.2020
# 2538573           2020  07.-09.02.2020
# 2538574           2020  07.-09.02.2020
# 2538575           2020  07.-09.02.2020
# ...                ...             ...
# 2762404           2020      03.10.2020
# 2762405           2020      03.10.2020
# 2762406           2020      03.10.2020
# 2762407           2020      03.10.2020
# 2762408           2020      03.10.2020
#
#                                       Event name Event distance/length  \
# 2538571  Taipei 48hr Ultra Marathon - 50mi (TPE)                  50mi
# 2538572  Taipei 48hr Ultra Marathon - 50mi (TPE)                  50mi
# 2538573  Taipei 48hr Ultra Marathon - 50mi (TPE)                  50mi
# 2538574  Taipei 48hr Ultra Marathon - 50mi (TPE)                  50mi
# 2538575  Taipei 48hr Ultra Marathon - 50mi (TPE)                  50mi
# ...

# %%
# Take the brackets out of "(USA)" out so we can filter by it

df.loc[df['Event name'] == 'Everglades 50 Mile Ultra Run (USA)'] \
['Event name'].str.split('(').str.get(1) \
.str.split(')').str.get(0)
# Out:
# 51923      USA
# 51924      USA
# 51925      USA
# 51926      USA
# 51927      USA
#           ...
# 6710397    USA
# 6710398    USA
# 6710399    USA
# 6710400    USA
# 6710401    USA
# Name: Event name, Length: 338, dtype: object

# %%
df.loc[df['Event name'].str.split('(').str.get(1) \
        .str.split(')').str.get(0) == 'USA']
# Out:
#          Year of event Event dates  \
# 55                2018  06.01.2018
# 56                2018  06.01.2018
# 57                2018  06.01.2018
# 58                2018  06.01.2018
# 59                2018  06.01.2018
# ...                ...         ...
# 7117228           2015  09.10.2015
# 7117229           2015  09.10.2015
# 7117230           2015  09.10.2015
# 7117231           2015  09.10.2015
# 7117232           2015  09.10.2015
#
#                                             Event name Event distance/length  \
# 55       Yankee Springs 50 Mile Winter Challenge (USA)                  50mi
# 56       Yankee Springs 50 Mile Winter Challenge (USA)                  50mi
# 57       Yankee Springs 50 Mile Winter Challenge (USA)                  50mi
# 58       Yankee Springs 50 Mile Winter Challenge (USA)                  50mi
# 59       Yankee Springs 50 Mile Winter Challenge (USA)                  50mi
# ...

# %%
# Combine all the filters together

# %%
df.loc[(df['Event distance/length'].isin(['50km', '50mi'])) &
        (df['Year of event']== 2020) & 
        (df['Event name'].str.split('(').str.get(1) \
        .str.split(')').str.get(0) == 'USA')]
# Out:
#          Year of event Event dates  \
# 2539945           2020  02.02.2020
# 2539946           2020  02.02.2020
# 2539947           2020  02.02.2020
# 2539948           2020  02.02.2020
# 2539949           2020  02.02.2020
# ...                ...         ...
# 2760957           2020  03.10.2020
# 2760958           2020  03.10.2020
# 2760959           2020  03.10.2020
# 2760960           2020  03.10.2020
# 2760961           2020  03.10.2020
#
#                                             Event name Event distance/length  \
# 2539945  West Seattle Beach Run - Winter Edition (USA)                  50km
# 2539946  West Seattle Beach Run - Winter Edition (USA)                  50km
# 2539947  West Seattle Beach Run - Winter Edition (USA)                  50km
# 2539948  West Seattle Beach Run - Winter Edition (USA)                  50km
# 2539949  West Seattle Beach Run - Winter Edition (USA)                  50km
# ...

# %%
# put the filter under a new df, df2, and look at the first five rows
df2 = df.loc[(df['Event distance/length'].isin(['50km', '50mi'])) &
        (df['Year of event']== 2020) & 
        (df['Event name'].str.split('(').str.get(1) \
        .str.split(')').str.get(0) == 'USA')]

df2.head(5)
# Out:
#          Year of event Event dates  \
# 2539945           2020  02.02.2020
# 2539946           2020  02.02.2020
# 2539947           2020  02.02.2020
# 2539948           2020  02.02.2020
# 2539949           2020  02.02.2020
#
#                                             Event name Event distance/length  \
# 2539945  West Seattle Beach Run - Winter Edition (USA)                  50km
# 2539946  West Seattle Beach Run - Winter Edition (USA)                  50km
# 2539947  West Seattle Beach Run - Winter Edition (USA)                  50km
# 2539948  West Seattle Beach Run - Winter Edition (USA)                  50km
# 2539949  West Seattle Beach Run - Winter Edition (USA)                  50km
#
#          Event number of finishers Athlete performance  \
# 2539945                         20           3:17:55 h
# 2539946                         20           4:02:32 h
# 2539947                         20           4:07:57 h
# 2539948                         20           4:22:02 h
# ...

# %%
# Lets see if the rows and col changed so we know we did it right
df2.shape
# Out:
# (26090, 13)

# %%
# completely remove the "(USA)" from event name and then get the first index

# %%
df2['Event name'].str.split('(').str.get(0)
# Out:
# 2539945    West Seattle Beach Run - Winter Edition
# 2539946    West Seattle Beach Run - Winter Edition
# 2539947    West Seattle Beach Run - Winter Edition
# 2539948    West Seattle Beach Run - Winter Edition
# 2539949    West Seattle Beach Run - Winter Edition
#                              ...
# 2760957     Yankee Springs Fall Trail Run Festival
# 2760958     Yankee Springs Fall Trail Run Festival
# 2760959     Yankee Springs Fall Trail Run Festival
# 2760960     Yankee Springs Fall Trail Run Festival
# 2760961     Yankee Springs Fall Trail Run Festival
# Name: Event name, Length: 26090, dtype: object

# %%
df2['Event name'] = df2['Event name'].str.split('(').str.get(0)
# Out:
# C:\Users\Natna\AppData\Local\Temp\ipykernel_13848\3473829760.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['Event name'] = df2['Event name'].str.split('(').str.get(0)

# %%
df2.head(5)
# Out:
#          Year of event Event dates                                Event name  \
# 2539945           2020  02.02.2020  West Seattle Beach Run - Winter Edition
# 2539946           2020  02.02.2020  West Seattle Beach Run - Winter Edition
# 2539947           2020  02.02.2020  West Seattle Beach Run - Winter Edition
# 2539948           2020  02.02.2020  West Seattle Beach Run - Winter Edition
# 2539949           2020  02.02.2020  West Seattle Beach Run - Winter Edition
#
#         Event distance/length  Event number of finishers Athlete performance  \
# 2539945                  50km                         20           3:17:55 h
# 2539946                  50km                         20           4:02:32 h
# 2539947                  50km                         20           4:07:57 h
# 2539948                  50km                         20           4:22:02 h
# 2539949                  50km                         20           4:27:34 h
#
# ...

# %%
# Clean up the athlete age

# %%
# get the age of the athletes under a new column 
df2['Athlete_Age'] = 2020 - df2['Athlete year of birth']
# Out:
# C:\Users\Natna\AppData\Local\Temp\ipykernel_13848\3639572179.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['Athlete_Age'] = 2020 - df2['Athlete year of birth']

# %%
# remove the "h" from athlete performance

# %%
df2['Athlete performance'] = df2['Athlete performance'].str.split(' ').str.get(0)
# Out:
# C:\Users\Natna\AppData\Local\Temp\ipykernel_13848\2477507555.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['Athlete performance'] = df2['Athlete performance'].str.split(' ').str.get(0)

# %%
df2.head()
# Out:
#          Year of event Event dates                                Event name  \
# 2539945           2020  02.02.2020  West Seattle Beach Run - Winter Edition
# 2539946           2020  02.02.2020  West Seattle Beach Run - Winter Edition
# 2539947           2020  02.02.2020  West Seattle Beach Run - Winter Edition
# 2539948           2020  02.02.2020  West Seattle Beach Run - Winter Edition
# 2539949           2020  02.02.2020  West Seattle Beach Run - Winter Edition
#
#         Event distance/length  Event number of finishers Athlete performance  \
# 2539945                  50km                         20             3:17:55
# 2539946                  50km                         20             4:02:32
# 2539947                  50km                         20             4:07:57
# 2539948                  50km                         20             4:22:02
# 2539949                  50km                         20             4:27:34
#
# ...

# %%
# drop unnecssary cols: Athlete Club, Althlete Country, Athlete Year of birth, Athlete Age Category
# Axis = 1 : so it knows we're dropping the cols

# %%
df2 = df2.drop(['Athlete club','Athlete country', 'Athlete year of birth', 
       'Athlete age category'], axis = 1)

# %%
df2.head()
# Out:
#          Year of event Event dates                                Event name  \
# 2539945           2020  02.02.2020  West Seattle Beach Run - Winter Edition
# 2539946           2020  02.02.2020  West Seattle Beach Run - Winter Edition
# 2539947           2020  02.02.2020  West Seattle Beach Run - Winter Edition
# 2539948           2020  02.02.2020  West Seattle Beach Run - Winter Edition
# 2539949           2020  02.02.2020  West Seattle Beach Run - Winter Edition
#
#         Event distance/length  Event number of finishers Athlete performance  \
# 2539945                  50km                         20             3:17:55
# 2539946                  50km                         20             4:02:32
# 2539947                  50km                         20             4:07:57
# 2539948                  50km                         20             4:22:02
# 2539949                  50km                         20             4:27:34
#
# ...

# %%
# clean up null values
# isna() : shows all the null values 
# .sum() : will total up all the null values

# %%
df2.isna().sum()
# Out:
# Year of event                  0
# Event dates                    0
# Event name                     0
# Event distance/length          0
# Event number of finishers      0
# Athlete performance            0
# Athlete gender                 0
# Athlete average speed          0
# Athlete ID                     0
# Athlete_Age                  233
# dtype: int64

# %%
# Shows the null values in the 'Athlete_Age' col
df2.loc[df2['Athlete_Age'].isna()==1]
# Out:
#          Year of event Event dates                           Event name  \
# 2547794           2020  25.01.2020        North Carolina Fat Ass 50 Km
# 2551331           2020  19.01.2020      Big Bend 50 - Fresno Creek 50K
# 2551336           2020  19.01.2020      Big Bend 50 - Fresno Creek 50K
# 2551344           2020  19.01.2020      Big Bend 50 - Fresno Creek 50K
# 2551348           2020  19.01.2020      Big Bend 50 - Fresno Creek 50K
# ...                ...         ...                                  ...
# 2746543           2020  17.10.2020     Black River Trail Classic 50 Km
# 2749869           2020  17.10.2020  MuleSkinner Endurance 50 Mile Race
# 2755985           2020  10.10.2020      Man Against Horse 50 Mile Race
# 2755994           2020  10.10.2020      Man Against Horse 50 Mile Race
# 2755997           2020  10.10.2020      Man Against Horse 50 Mile Race
#
#         Event distance/length  Event number of finishers Athlete performance  \
# ...

# %%
# drop the null values and overwrite the original df2
df2 = df2.dropna()

# %%
df2.shape
# Out:
# (25857, 10)

# %%
# check for duplicate values

# %%
df2.duplicated().sum()

# df2.loc[df2.duplicated() == True] : another way to see
# Out:
# 0

# %%
# reset index

# %%
# Reset_index so we can have the numbers in the correct order

df2.reset_index(drop = True)
# Out:
#        Year of event Event dates                                Event name  \
# 0               2020  02.02.2020  West Seattle Beach Run - Winter Edition
# 1               2020  02.02.2020  West Seattle Beach Run - Winter Edition
# 2               2020  02.02.2020  West Seattle Beach Run - Winter Edition
# 3               2020  02.02.2020  West Seattle Beach Run - Winter Edition
# 4               2020  02.02.2020  West Seattle Beach Run - Winter Edition
# ...              ...         ...                                       ...
# 25852           2020  03.10.2020   Yankee Springs Fall Trail Run Festival
# 25853           2020  03.10.2020   Yankee Springs Fall Trail Run Festival
# 25854           2020  03.10.2020   Yankee Springs Fall Trail Run Festival
# 25855           2020  03.10.2020   Yankee Springs Fall Trail Run Festival
# 25856           2020  03.10.2020   Yankee Springs Fall Trail Run Festival
#
#       Event distance/length  Event number of finishers Athlete performance  \
# ...

# %%
# fix data types

# %%
df2.dtypes
# Out:
# Year of event                  int64
# Event dates                   object
# Event name                    object
# Event distance/length         object
# Event number of finishers      int64
# Athlete performance           object
# Athlete gender                object
# Athlete average speed         object
# Athlete ID                     int64
# Athlete_Age                  float64
# dtype: object

# %%
df2['Athlete_Age'] = df2['Athlete_Age'].astype(int)

# df2.['Athlete_Age'] = pd.to_int(df2['Athlete_Age']) : another way

# %%
df2['Athlete average speed'] = df2['Athlete average speed'].astype(float)

# %%
df2.dtypes
# Out:
# Year of event                  int64
# Event dates                   object
# Event name                    object
# Event distance/length         object
# Event number of finishers      int64
# Athlete performance           object
# Athlete gender                object
# Athlete average speed        float64
# Athlete ID                     int64
# Athlete_Age                    int32
# dtype: object

# %%
df2.head()
# Out:
#          Year of event Event dates                                Event name  \
# 2539945           2020  02.02.2020  West Seattle Beach Run - Winter Edition
# 2539946           2020  02.02.2020  West Seattle Beach Run - Winter Edition
# 2539947           2020  02.02.2020  West Seattle Beach Run - Winter Edition
# 2539948           2020  02.02.2020  West Seattle Beach Run - Winter Edition
# 2539949           2020  02.02.2020  West Seattle Beach Run - Winter Edition
#
#         Event distance/length  Event number of finishers Athlete performance  \
# 2539945                  50km                         20             3:17:55
# 2539946                  50km                         20             4:02:32
# 2539947                  50km                         20             4:07:57
# 2539948                  50km                         20             4:22:02
# 2539949                  50km                         20             4:27:34
#
# ...

# %%
# Rename columns

# %%
df2.columns
# Out:
# Index(['Year of event', 'Event dates', 'Event name', 'Event distance/length',
#        'Event number of finishers', 'Athlete performance', 'Athlete gender',
#        'Athlete average speed', 'Athlete ID', 'Athlete_Age'],
#       dtype='object')

# %%
df2 = df2.rename(columns = {'Year of event':'year',
                            'Event dates':'race_day', 
                            'Event name':'race_name', 
                            'Event distance/length':'race_length',
                            'Event number of finishers':'race_number_of_finishers', 
                            'Athlete performance':'athlete_performance', 
                            'Athlete gender':'athlete_gender',
                            'Athlete average speed':'athlete_avg_speed', 
                            'Athlete ID':'athlete_id',
                            'Athlete_Age':'athlete_age'})

# %%
df2.head()
# Out:
#          year    race_day                                 race_name  \
# 2539945  2020  02.02.2020  West Seattle Beach Run - Winter Edition
# 2539946  2020  02.02.2020  West Seattle Beach Run - Winter Edition
# 2539947  2020  02.02.2020  West Seattle Beach Run - Winter Edition
# 2539948  2020  02.02.2020  West Seattle Beach Run - Winter Edition
# 2539949  2020  02.02.2020  West Seattle Beach Run - Winter Edition
#
#         race_length  race_number_of_finishers athlete_performance  \
# 2539945        50km                        20             3:17:55
# 2539946        50km                        20             4:02:32
# 2539947        50km                        20             4:07:57
# 2539948        50km                        20             4:22:02
# 2539949        50km                        20             4:27:34
#
#         athlete_gender  athlete_avg_speed  athlete_id  athlete_age
# 2539945              M             15.158       71287           29
# ...

# %%
# Reorder columns under a new df called df3

df2.columns
# Out:
# Index(['year', 'race_day', 'race_name', 'race_length',
#        'race_number_of_finishers', 'athlete_performance', 'athlete_gender',
#        'athlete_avg_speed', 'athlete_id', 'athlete_age'],
#       dtype='object')

# %%
df3 = df2[['race_day','race_name', 'race_length','year', 
            'race_number_of_finishers', 'athlete_id',
            'athlete_gender', 'athlete_performance', 
           'athlete_avg_speed', 'athlete_age']]

# %%
df3.head()
# Out:
#            race_day                                 race_name race_length  \
# 2539945  02.02.2020  West Seattle Beach Run - Winter Edition         50km
# 2539946  02.02.2020  West Seattle Beach Run - Winter Edition         50km
# 2539947  02.02.2020  West Seattle Beach Run - Winter Edition         50km
# 2539948  02.02.2020  West Seattle Beach Run - Winter Edition         50km
# 2539949  02.02.2020  West Seattle Beach Run - Winter Edition         50km
#
#          year  race_number_of_finishers  athlete_id athlete_gender  \
# 2539945  2020                        20       71287              M
# 2539946  2020                        20      629508              M
# 2539947  2020                        20       64838              M
# 2539948  2020                        20      704450              M
# 2539949  2020                        20      810281              M
#
#         athlete_performance  athlete_avg_speed  athlete_age
# ...

# %% [markdown]
# ## Visualization

# %%
# histogram based off the difference race_length (50k and 50mi)

# %%
sns.histplot(df3['race_length'])
# Out:
# <Axes: xlabel='race_length', ylabel='Count'>

# %%
# histogram based off the difference race lengths (50k and 50mi) and the athlete's gender
sns.histplot(df3, x ='race_length', hue = 'athlete_gender')
# Out:
# <Axes: xlabel='race_length', ylabel='Count'>

# %%
# distribution plot to see the athlete speed for the 50mi race
sns.displot(df3[df3['race_length']== '50mi']['athlete_avg_speed'])

# %%
# Athlete_avg_speed by race_length, gender and quartile 
sns.violinplot(data = df3, x='race_length', 
               y='athlete_avg_speed', hue='athlete_gender',
               split = True, # Split the violins for each gender
               inner = 'quart', # Show quartiles inside the violins
              linewidth = 1)
# Out:
# <Axes: xlabel='race_length', ylabel='athlete_avg_speed'>

# %%
# Trying to find a corr() betweeen the athlete's_avg_speed and the athlete_age based on their gender 
sns.lmplot(data=df3, x='athlete_age', y='athlete_avg_speed', 
           hue='athlete_gender')

# %% [markdown]
# ## Extra Analysis

# %%
# Difference in speed for the 50k & 50mi by male and female

# %%
df3.groupby(['race_length', 'athlete_gender']) \
            .agg({'athlete_avg_speed':'mean'}) \
            .reset_index()
# Out:
#   race_length athlete_gender  athlete_avg_speed
# 0        50km              F           7.083011
# 1        50km              M           7.738985
# 2        50mi              F           6.834371
# 3        50mi              M           7.257633

# %%
# What age groups are the best in the 50m Race (20+ races min) (show 15)

# %%
df3.query('race_length == "50mi"').groupby('athlete_age') \
            ['athlete_avg_speed'].agg(['mean', 'count']) \
            .sort_values('mean', ascending=False).query('count > 19') \
            .head(15)
# Out:
#                  mean  count
# athlete_age
# 29           7.902252    135
# 23           7.779800     55
# 28           7.575252    107
# 30           7.569204    157
# 25           7.540923     91
# 31           7.451638    138
# 38           7.430022    231
# 35           7.422359    195
# 36           7.403854    185
# 26           7.379800     75
# 33           7.379188    149
# 22           7.367902     41
# 24           7.354274     73
# 42           7.327656    209
# 34           7.319011    182

# %%
# What age groups are the worst in the 50m Race (20 + races min) (show 20)

# %%
df3.query('race_length == "50mi"').groupby('athlete_age') \
            ['athlete_avg_speed'].agg(['mean', 'count']) \
            .sort_values('mean', ascending=True).query('count > 19') \
            .head(20)
# Out:
#                  mean  count
# athlete_age
# 60           6.261788     33
# 62           6.272730     37
# 61           6.358355     31
# 63           6.514806     31
# 58           6.582328     67
# 64           6.620727     22
# 50           6.671541    172
# 59           6.672072     83
# 48           6.696853    136
# 56           6.708373     67
# 53           6.736969     96
# 57           6.783205     78
# 49           6.789553    159
# 54           6.805506     83
# 55           6.828623     69
# 52           6.847400    130
# 43           6.884225    187
# 46           6.897236    174
# 51           7.019379    124
# 44           7.052642    179

# %%
# Seasons for the data ->  Are runners slower in the Summer than Winter?

#Spring 3-5
#Summer 6-8
#Fall 9-11
#Winter 12-2

# Spilt between two decimals

# %%
# create a new col called race_month by extract the month number from race_day
df3['race_month'] = df3['race_day'].str.split('.').str.get(1).astype(int)
# Out:
# C:\Users\Natna\AppData\Local\Temp\ipykernel_13848\3078284804.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df3['race_month'] = df3['race_day'].str.split('.').str.get(1).astype(int)

# %%
# Create a new col called 'race_season' and name them by the season (ex: Fall, Summer, etc.) 
df3['race_season'] = df3['race_month'].apply(lambda x: 'Winter' if x > 11 else 'Fall' if x > 8 else 'Summer' \
                                                       if x > 5 else 'Spring' if x > 2 else 'Winter')
# Out:
# C:\Users\Natna\AppData\Local\Temp\ipykernel_13848\754402717.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df3['race_season'] = df3['race_month'].apply(lambda x: 'Winter' if x > 11 else 'Fall' if x > 8 else 'Summer' \

# %%
df3.head()
# Out:
#            race_day                                 race_name race_length  \
# 2539945  02.02.2020  West Seattle Beach Run - Winter Edition         50km
# 2539946  02.02.2020  West Seattle Beach Run - Winter Edition         50km
# 2539947  02.02.2020  West Seattle Beach Run - Winter Edition         50km
# 2539948  02.02.2020  West Seattle Beach Run - Winter Edition         50km
# 2539949  02.02.2020  West Seattle Beach Run - Winter Edition         50km
#
#          year  race_number_of_finishers  athlete_id athlete_gender  \
# 2539945  2020                        20       71287              M
# 2539946  2020                        20      629508              M
# 2539947  2020                        20       64838              M
# 2539948  2020                        20      704450              M
# 2539949  2020                        20      810281              M
#
#         athlete_performance  athlete_avg_speed  athlete_age  race_month  \
# ...

# %%
# we find out runners are slower in the Summer than Winter but we notice there are more racers in Winter than Summer
df3.groupby('race_season')['athlete_avg_speed'].agg(['mean', 'count']).sort_values('mean', ascending=False)
# Out:
#                  mean  count
# race_season
# Spring       7.684430   3294
# Winter       7.518187  11595
# Fall         7.406619   8315
# Summer       6.869336   2653

# %%
# We try to see if it's true for '50 miler only' and the same seems to be the true

# %%
df3.query('race_length == "50mi"').groupby('race_season')['athlete_avg_speed'].agg(['mean', 'count']).sort_values('mean', ascending=False)
# Out:
#                  mean  count
# race_season
# Fall         7.511585   1997
# Spring       7.082557    836
# Winter       7.048442   1977
# Summer       6.505776    817
